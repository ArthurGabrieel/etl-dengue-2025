# %% [markdown]
# # 🔄 ETL: Raw → Silver | Dengue SINAN 2024-2025
#
# **Objetivo:** Transformar dados brutos (Bronze) em dados tratados (Silver)
#
# **Tecnologias:** Apache Spark (PySpark) + PostgreSQL
#
# ---
#
# ### Pipeline de Transformação
#
# | Etapa | Descrição |
# |-------|-----------|
# | 1. Configuração | Inicializar SparkSession com driver JDBC |
# | 2. Ingestão | Carregar CSV do SINAN |
# | 3. Seleção de Colunas | Manter apenas campos epidemiológicos |
# | 4. Tratamento de Datas | Converter para DateType |
# | 5. Decodificação | Converter códigos SINAN para descrições |
# | 6. Tratamento de Idade | Lógica específica do SINAN |
# | 7. Colunas Derivadas | Flags e indicadores |
# | 8. Validação | Qualidade dos dados |
# | 9. Persistência | Salvar no PostgreSQL (camada Silver) |

# %% [markdown]
# ---
# ## 1. Configuração

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType, FloatType, StringType
import os

# ============================================================
# CONFIGURAÇÃO DO SPARK
# ============================================================

# Caminho para o driver JDBC do PostgreSQL (local do projeto)
JDBC_DRIVER_PATH = os.path.abspath("../jars/postgresql-42.7.5.jar")

# Verificar se o driver existe
if not os.path.exists(JDBC_DRIVER_PATH):
    raise FileNotFoundError(f"Driver JDBC não encontrado em: {JDBC_DRIVER_PATH}")

print(f"📦 Driver JDBC: {JDBC_DRIVER_PATH}")

spark = SparkSession.builder \
    .appName("Dengue-ETL-Silver") \
    .config("spark.sql.legacy.timeParserPolicy", "CORRECTED") \
    .config("spark.driver.memory", "4g") \
    .config("spark.jars", JDBC_DRIVER_PATH) \
    .config("spark.driver.extraClassPath", JDBC_DRIVER_PATH) \
    .config("spark.executor.extraClassPath", JDBC_DRIVER_PATH) \
    .getOrCreate()

# Configuração do PostgreSQL
POSTGRES_CONFIG = {
    "host": "localhost",
    "port": "5432",
    "database": "gis",
    "user": "postgres",
    "password": "postgres"
}

JDBC_URL = f"jdbc:postgresql://{POSTGRES_CONFIG['host']}:{POSTGRES_CONFIG['port']}/{POSTGRES_CONFIG['database']}"

# Caminhos
RAW_PATH = "../Data_Layer/raw/DENGBR25.csv"

# ============================================================
# DICIONÁRIOS DE MAPEAMENTO (SINAN)
# ============================================================

UF_MAP = {
    11: 'RO', 12: 'AC', 13: 'AM', 14: 'RR', 15: 'PA', 16: 'AP', 17: 'TO',
    21: 'MA', 22: 'PI', 23: 'CE', 24: 'RN', 25: 'PB', 26: 'PE', 27: 'AL',
    28: 'SE', 29: 'BA', 31: 'MG', 32: 'ES', 33: 'RJ', 35: 'SP', 41: 'PR',
    42: 'SC', 43: 'RS', 50: 'MS', 51: 'MT', 52: 'GO', 53: 'DF'
}

SEXO_MAP = {'M': 'Masculino', 'F': 'Feminino', 'I': 'Ignorado'}

RACA_MAP = {1: 'Branca', 2: 'Preta', 3: 'Amarela', 4: 'Parda', 5: 'Indígena', 9: 'Ignorado'}

ESCOLARIDADE_MAP = {
    0: 'Analfabeto', 1: '1-4 serie incompleta', 2: '4 serie completa',
    3: '5-8 serie incompleta', 4: 'Fundamental completo', 5: 'Medio incompleto',
    6: 'Medio completo', 7: 'Superior incompleto', 8: 'Superior completo',
    9: 'Ignorado', 10: 'Nao se aplica'
}

CLASSIFICACAO_MAP = {
    5: 'Descartado', 10: 'Dengue', 11: 'Dengue com Sinais de Alarme',
    12: 'Dengue Grave', 13: 'Chikungunya'
}

CRITERIO_MAP = {1: 'Laboratorial', 2: 'Clinico-epidemiologico', 3: 'Em investigacao'}

EVOLUCAO_MAP = {1: 'Cura', 2: 'Obito pelo agravo', 3: 'Obito por outras causas', 9: 'Ignorado'}

GESTANTE_MAP = {
    1: '1 Trimestre', 2: '2 Trimestre', 3: '3 Trimestre',
    4: 'Idade gestacional ignorada', 5: 'Nao', 6: 'Nao se aplica', 9: 'Ignorado'
}

AUTOCTONE_MAP = {1: 'Autoctone', 2: 'Importado', 3: 'Indeterminado'}

print("✅ SparkSession iniciada")
print(f"📊 Versão do Spark: {spark.version}")
print(f"🔗 JDBC URL: {JDBC_URL}")
# Out:
# 📦 Driver JDBC: /Users/arthur/dev/etl-dengue-2025/jars/postgresql-42.7.5.jar
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/18 18:11:04 WARN Utils: Your hostname, MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.15.7 instead (on interface en0)
# 26/01/18 18:11:04 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 26/01/18 18:11:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ✅ SparkSession iniciada
# 📊 Versão do Spark: 4.0.1
# 🔗 JDBC URL: jdbc:postgresql://localhost:5432/gis

# %% [markdown]
# ---
# ## 2. Carregar Dados Raw

# %%
# Carregar dados brutos do CSV
df_raw = spark.read \
    .option("header", "true") \
    .option("delimiter", ",") \
    .option("encoding", "iso-8859-1") \
    .option("inferSchema", "true") \
    .csv(RAW_PATH)

print(f"📁 Registros carregados: {df_raw.count():,}")
print(f"📊 Colunas originais: {len(df_raw.columns)}")
# Out:
# 📁 Registros carregados: 1,668,787
# 📊 Colunas originais: 121

# %% [markdown]
# ---
# ## 3. Seleção de Colunas
#
# Remover colunas com >90% de valores nulos e manter apenas as relevantes para análise epidemiológica.

# %%
# Colunas essenciais para análise epidemiológica
COLUNAS_ESSENCIAIS = [
    # Identificação e Notificação
    'TP_NOT', 'ID_AGRAVO', 'DT_NOTIFIC', 'SEM_NOT', 'NU_ANO',
    
    # Localização
    'SG_UF_NOT', 'ID_MUNICIP', 'ID_MN_RESI', 'SG_UF',
    
    # Dados do Paciente
    'DT_SIN_PRI', 'SEM_PRI', 'NU_IDADE_N', 'CS_SEXO', 
    'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
    
    # Sintomas Principais
    'FEBRE', 'MIALGIA', 'CEFALEIA', 'EXANTEMA', 'VOMITO', 
    'NAUSEA', 'DOR_COSTAS', 'ARTRALGIA', 'DOR_RETRO',
    
    # Comorbidades
    'DIABETES', 'HIPERTENSA', 'RENAL', 'HEPATOPAT',
    
    # Exames e Diagnóstico
    'RESUL_SORO', 'RESUL_NS1', 'RESUL_PCR_', 'SOROTIPO',
    
    # Classificação e Evolução
    'HOSPITALIZ', 'CLASSI_FIN', 'CRITERIO', 'EVOLUCAO', 
    'DT_OBITO', 'DT_ENCERRA',
    
    # Sinais de Alarme
    'ALRM_HIPOT', 'ALRM_PLAQ', 'ALRM_VOM', 'ALRM_SANG',
    'ALRM_HEMAT', 'ALRM_ABDOM', 'ALRM_LETAR', 'ALRM_HEPAT',
    
    # Autoctonia
    'TPAUTOCTO', 'COUFINF', 'COPAISINF'
]

# Filtrar apenas colunas que existem no dataset
colunas_disponiveis = [col for col in COLUNAS_ESSENCIAIS if col in df_raw.columns]
colunas_faltantes = [col for col in COLUNAS_ESSENCIAIS if col not in df_raw.columns]

print(f"✅ Colunas selecionadas: {len(colunas_disponiveis)}")
if colunas_faltantes:
    print(f"⚠️ Colunas não encontradas: {colunas_faltantes}")
# Out:
# ✅ Colunas selecionadas: 50

# %%
# Criar DataFrame com colunas selecionadas
df = df_raw.select(colunas_disponiveis)

print(f"✅ DataFrame criado com {len(df.columns)} colunas")
df.printSchema()
# Out:
# ✅ DataFrame criado com 50 colunas
# root
#  |-- TP_NOT: integer (nullable = true)
#  |-- ID_AGRAVO: string (nullable = true)
#  |-- DT_NOTIFIC: date (nullable = true)
#  |-- SEM_NOT: integer (nullable = true)
#  |-- NU_ANO: integer (nullable = true)
#  |-- SG_UF_NOT: integer (nullable = true)
#  |-- ID_MUNICIP: integer (nullable = true)
#  |-- ID_MN_RESI: integer (nullable = true)
#  |-- SG_UF: integer (nullable = true)
#  |-- DT_SIN_PRI: date (nullable = true)
#  |-- SEM_PRI: integer (nullable = true)
#  |-- NU_IDADE_N: integer (nullable = true)
#  |-- CS_SEXO: string (nullable = true)
#  |-- CS_GESTANT: integer (nullable = true)
#  |-- CS_RACA: integer (nullable = true)
#  |-- CS_ESCOL_N: integer (nullable = true)
#  |-- FEBRE: integer (nullable = true)
#  |-- MIALGIA: integer (nullable = true)
#  |-- CEFALEIA: integer (nullable = true)
#  |-- EXANTEMA: integer (nullable = true)
#  |-- VOMITO: integer (nullable = true)
#  |-- NAUSEA: integer (nullable = true)
# ...

# %% [markdown]
# ---
# ## 4. Tratamento de Datas
#
# Converter campos de data para formato datetime e criar variáveis temporais.

# %%
# Converter colunas de data (formato DD/MM/YYYY do SINAN)
COLUNAS_DATA = ['DT_NOTIFIC', 'DT_SIN_PRI', 'DT_OBITO', 'DT_ENCERRA']

for col in COLUNAS_DATA:
    if col in df.columns:
        df = df.withColumn(col, F.to_date(F.col(col), "dd/MM/yyyy"))

# Criar variáveis temporais derivadas
df = df.withColumn("ano_notificacao", F.year(F.col("DT_NOTIFIC")))
df = df.withColumn("mes_notificacao", F.month(F.col("DT_NOTIFIC")))
df = df.withColumn("semana_epi", F.weekofyear(F.col("DT_SIN_PRI")))

# Calcular intervalo entre sintomas e notificação (em dias)
df = df.withColumn("dias_notificacao", F.datediff(F.col("DT_NOTIFIC"), F.col("DT_SIN_PRI")))

print("✅ Datas convertidas e variáveis temporais criadas")

# Mostrar período dos dados
df.select(F.min("DT_NOTIFIC").alias("inicio"), F.max("DT_NOTIFIC").alias("fim")).show()
# Out:
# ✅ Datas convertidas e variáveis temporais criadas
# [Stage 5:>                                                        (0 + 10) / 10]
# +----------+----------+
# |    inicio|       fim|
# +----------+----------+
# |2024-12-29|2026-01-05|
# +----------+----------+

# %% [markdown]
# ---
# ## 5. Mapeamento de Códigos
#
# Converter códigos numéricos do SINAN para descrições legíveis.

# %%
# Criar mapeamentos como expressões Spark (CASE WHEN)
from pyspark.sql.functions import create_map, lit, col, when, coalesce

# Função auxiliar para criar mapeamentos
def create_mapping_expr(column, mapping_dict, default="Nao informado"):
    """Cria expressão de mapeamento usando CASE WHEN"""
    expr = None
    for key, value in mapping_dict.items():
        condition = col(column) == key
        if expr is None:
            expr = when(condition, lit(value))
        else:
            expr = expr.when(condition, lit(value))
    return expr.otherwise(lit(default))

# Extrair UF do código do município (2 primeiros dígitos)
df = df.withColumn("uf_residencia", (F.col("ID_MN_RESI") / 100000).cast(IntegerType()))

# Aplicar mapeamentos descritivos
df = df.withColumn("uf_sigla", create_mapping_expr("SG_UF_NOT", UF_MAP, "Desconhecido"))
df = df.withColumn("sexo_desc", create_mapping_expr("CS_SEXO", SEXO_MAP, "Nao informado"))
df = df.withColumn("raca_desc", create_mapping_expr("CS_RACA", RACA_MAP, "Nao informado"))
df = df.withColumn("escolaridade_desc", create_mapping_expr("CS_ESCOL_N", ESCOLARIDADE_MAP, "Nao informado"))
df = df.withColumn("classificacao_desc", create_mapping_expr("CLASSI_FIN", CLASSIFICACAO_MAP, "Em investigacao"))
df = df.withColumn("criterio_desc", create_mapping_expr("CRITERIO", CRITERIO_MAP, "Nao informado"))
df = df.withColumn("evolucao_desc", create_mapping_expr("EVOLUCAO", EVOLUCAO_MAP, "Em investigacao"))
df = df.withColumn("gestante_desc", create_mapping_expr("CS_GESTANT", GESTANTE_MAP, "Nao informado"))
df = df.withColumn("autoctone_desc", create_mapping_expr("TPAUTOCTO", AUTOCTONE_MAP, "Nao informado"))

print("✅ Códigos mapeados para descrições")

# Verificar distribuição da classificação
print("\n📊 Distribuição de Classificação Final:")
df.groupBy("classificacao_desc").count().orderBy(F.desc("count")).show()
# Out:
# ✅ Códigos mapeados para descrições
#
# 📊 Distribuição de Classificação Final:
# +--------------------+-------+
# |  classificacao_desc|  count|
# +--------------------+-------+
# |              Dengue|1411105|
# |     Em investigacao| 220469|
# |Dengue com Sinais...|  34577|
# |        Dengue Grave|   2636|
# +--------------------+-------+

# %% [markdown]
# ---
# ## 6. Tratamento de Idade
#
# Converter código de idade do SINAN para idade em anos.

# %%
# ============================================================
# TRATAMENTO DE IDADE (Lógica específica do SINAN)
# ============================================================
# Formato SINAN: TUUU onde T é o tipo e UUU é o valor
# - 1: Horas → 0 anos
# - 2: Dias → 0 anos
# - 3: Meses → valor/12
# - 4: Anos → valor direto

df = df.withColumn(
    "idade_anos",
    F.when(F.col("NU_IDADE_N").isNull(), None)
    .when((F.col("NU_IDADE_N") / 1000).cast(IntegerType()) == 1, 0)  # Horas
    .when((F.col("NU_IDADE_N") / 1000).cast(IntegerType()) == 2, 0)  # Dias
    .when((F.col("NU_IDADE_N") / 1000).cast(IntegerType()) == 3,     # Meses
          (F.col("NU_IDADE_N") % 1000) / 12)
    .when((F.col("NU_IDADE_N") / 1000).cast(IntegerType()) == 4,     # Anos
          (F.col("NU_IDADE_N") % 1000))
    .otherwise(None)
    .cast(FloatType())
)

# Criar faixas etárias
df = df.withColumn(
    "faixa_etaria",
    F.when(F.col("idade_anos").isNull(), "Nao informado")
    .when(F.col("idade_anos") < 1, "< 1 ano")
    .when(F.col("idade_anos") < 5, "1-4 anos")
    .when(F.col("idade_anos") < 10, "5-9 anos")
    .when(F.col("idade_anos") < 20, "10-19 anos")
    .when(F.col("idade_anos") < 40, "20-39 anos")
    .when(F.col("idade_anos") < 60, "40-59 anos")
    .otherwise("60+ anos")
)

print("✅ Idade convertida e faixas etárias criadas")
print("\n📊 Distribuição por Faixa Etária:")
df.groupBy("faixa_etaria").count().orderBy(F.desc("count")).show()
# Out:
# ✅ Idade convertida e faixas etárias criadas
#
# 📊 Distribuição por Faixa Etária:
# +-------------+------+
# | faixa_etaria| count|
# +-------------+------+
# |   20-39 anos|591032|
# |   40-59 anos|451059|
# |   10-19 anos|239977|
# |     60+ anos|237379|
# |     5-9 anos| 89138|
# |     1-4 anos| 45475|
# |      < 1 ano| 14720|
# |Nao informado|     7|
# +-------------+------+

# %% [markdown]
# ---
# ## 7. Colunas Derivadas para Análise
#
# Criar indicadores úteis para análise epidemiológica.

# %%
# ============================================================
# COLUNAS DERIVADAS (FLAGS E INDICADORES)
# ============================================================

# Flag: Caso confirmado de Dengue (10, 11, 12)
df = df.withColumn("fl_confirmado", 
    F.when(F.col("CLASSI_FIN").isin([10, 11, 12]), 1).otherwise(0))

# Flag: Caso grave (Dengue c/ Alarme ou Grave)
df = df.withColumn("fl_grave", 
    F.when(F.col("CLASSI_FIN").isin([11, 12]), 1).otherwise(0))

# Flag: Óbito
df = df.withColumn("fl_obito", 
    F.when(F.col("EVOLUCAO") == 2, 1).otherwise(0))

# Flag: Hospitalizado
df = df.withColumn("fl_hospitalizado", 
    F.when(F.col("HOSPITALIZ") == 1, 1).otherwise(0))

# Contar sintomas presentes (1 = Sim)
SINTOMAS_COLS = ['FEBRE', 'MIALGIA', 'CEFALEIA', 'EXANTEMA', 'VOMITO', 
                 'NAUSEA', 'DOR_COSTAS', 'ARTRALGIA', 'DOR_RETRO']
sintomas_disponiveis = [c for c in SINTOMAS_COLS if c in df.columns]

if sintomas_disponiveis:
    df = df.withColumn("qtd_sintomas", 
        sum([F.when(F.col(c) == 1, 1).otherwise(0) for c in sintomas_disponiveis]))

# Contar sinais de alarme
ALARME_COLS = ['ALRM_HIPOT', 'ALRM_PLAQ', 'ALRM_VOM', 'ALRM_SANG',
               'ALRM_HEMAT', 'ALRM_ABDOM', 'ALRM_LETAR', 'ALRM_HEPAT']
alarme_disponiveis = [c for c in ALARME_COLS if c in df.columns]

if alarme_disponiveis:
    df = df.withColumn("qtd_alarmes",
        sum([F.when(F.col(c) == 1, 1).otherwise(0) for c in alarme_disponiveis]))

# Flag: Possui comorbidade
COMORBIDADE_COLS = ['DIABETES', 'HIPERTENSA', 'RENAL', 'HEPATOPAT']
comorbidade_disponiveis = [c for c in COMORBIDADE_COLS if c in df.columns]

if comorbidade_disponiveis:
    df = df.withColumn("fl_comorbidade",
        F.when(F.greatest(*[F.col(c) for c in comorbidade_disponiveis]) == 1, 1).otherwise(0))

print("✅ Colunas derivadas criadas")

# Resumo dos indicadores
df.select(
    F.sum("fl_confirmado").alias("casos_confirmados"),
    F.sum("fl_grave").alias("casos_graves"),
    F.sum("fl_obito").alias("obitos"),
    F.sum("fl_hospitalizado").alias("hospitalizados")
).show()
# Out:
# ✅ Colunas derivadas criadas
# +-----------------+------------+------+--------------+
# |casos_confirmados|casos_graves|obitos|hospitalizados|
# +-----------------+------------+------+--------------+
# |          1448318|       37213|  1773|         72708|
# +-----------------+------------+------+--------------+

# %% [markdown]
# ---
# ## 8. Limpeza e Validação de Dados

# %%
# ============================================================
# ANÁLISE DE QUALIDADE DOS DADOS
# ============================================================

total_registros = df.count()

# Validações
validacoes = [
    ("Datas de notificação válidas", df.filter(F.col("DT_NOTIFIC").isNotNull()).count()),
    ("UF de notificação válida", df.filter(F.col("uf_sigla") != "Desconhecido").count()),
    ("Classificação preenchida", df.filter(F.col("CLASSI_FIN").isNotNull()).count()),
    ("Idade válida (0-120 anos)", df.filter(F.col("idade_anos").between(0, 120)).count()),
    ("Intervalo notificação válido", df.filter(F.col("dias_notificacao").between(-7, 365)).count())
]

print("📋 VALIDAÇÕES DE QUALIDADE")
print("=" * 60)
for nome, validos in validacoes:
    pct = (validos / total_registros) * 100
    status = "✅" if pct >= 95 else "⚠️" if pct >= 80 else "❌"
    print(f"{status} {nome}: {validos:,}/{total_registros:,} ({pct:.1f}%)")
# Out:
# [Stage 32:>                                                       (0 + 10) / 10]
# 📋 VALIDAÇÕES DE QUALIDADE
# ...
# ✅ Datas de notificação válidas: 1,668,787/1,668,787 (100.0%)
# ✅ UF de notificação válida: 1,668,787/1,668,787 (100.0%)
# ✅ Classificação preenchida: 1,623,107/1,668,787 (97.3%)
# ✅ Idade válida (0-120 anos): 1,668,741/1,668,787 (100.0%)
# ✅ Intervalo notificação válido: 1,668,770/1,668,787 (100.0%)

# %%
# ============================================================
# TRATAMENTO DE VALORES INVÁLIDOS
# ============================================================

# Substituir idades fora do range por null
df = df.withColumn("idade_anos",
    F.when(F.col("idade_anos").between(0, 120), F.col("idade_anos")).otherwise(None))

# Limpar intervalos de notificação absurdos
df = df.withColumn("dias_notificacao",
    F.when(F.col("dias_notificacao").between(-7, 365), F.col("dias_notificacao")).otherwise(None))

# Atualizar faixa etária para idades que ficaram nulas
df = df.withColumn("faixa_etaria",
    F.when(F.col("idade_anos").isNull(), "Nao informado").otherwise(F.col("faixa_etaria")))

print("✅ Valores inválidos tratados")
# Out:
# ✅ Valores inválidos tratados

# %% [markdown]
# ---
# ## 9. Organização Final e Exportação

# %%
# ============================================================
# RENOMEAR COLUNAS PARA SNAKE_CASE (Padrão PostgreSQL)
# ============================================================

rename_map = {
    "TP_NOT": "tipo_notificacao",
    "ID_AGRAVO": "id_agravo",
    "DT_NOTIFIC": "data_notificacao",
    "SEM_NOT": "semana_notificacao",
    "NU_ANO": "ano_dados",
    "SG_UF_NOT": "uf_notificacao_cod",
    "ID_MUNICIP": "id_municipio_notificacao",
    "ID_MN_RESI": "id_municipio_residencia",
    "SG_UF": "uf_residencia_cod",
    "DT_SIN_PRI": "data_sintomas",
    "SEM_PRI": "semana_sintomas",
    "NU_IDADE_N": "idade_codigo_sinan",
    "CS_SEXO": "sexo_cod",
    "CS_GESTANT": "gestante_cod",
    "CS_RACA": "raca_cod",
    "CS_ESCOL_N": "escolaridade_cod",
    "HOSPITALIZ": "hospitalizado_cod",
    "CLASSI_FIN": "classificacao_cod",
    "CRITERIO": "criterio_cod",
    "EVOLUCAO": "evolucao_cod",
    "DT_OBITO": "data_obito",
    "DT_ENCERRA": "data_encerramento",
    "TPAUTOCTO": "autoctone_cod",
    "COUFINF": "uf_infeccao_cod",
    "COPAISINF": "pais_infeccao_cod"
}

# Aplicar renomeação
for old_name, new_name in rename_map.items():
    if old_name in df.columns:
        df = df.withColumnRenamed(old_name, new_name)

print(f"✅ Colunas renomeadas para snake_case")
print(f"📊 Total de colunas no DataFrame final: {len(df.columns)}")
# Out:
# ✅ Colunas renomeadas para snake_case
# 📊 Total de colunas no DataFrame final: 73

# %%
# ============================================================
# SALVAR NO POSTGRESQL (CAMADA SILVER)
# ============================================================

TABLE_NAME = "dengue_silver"

# Propriedades de conexão JDBC
jdbc_properties = {
    "user": POSTGRES_CONFIG["user"],
    "password": POSTGRES_CONFIG["password"],
    "driver": "org.postgresql.Driver"
}

# Escrever no PostgreSQL
df.write \
    .mode("overwrite") \
    .jdbc(url=JDBC_URL, table=TABLE_NAME, properties=jdbc_properties)

print(f"✅ Dados salvos no PostgreSQL")
print(f"📊 Tabela: {TABLE_NAME}")
print(f"📁 Registros: {df.count():,}")
# Out:
# 26/01/18 18:11:20 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ✅ Dados salvos no PostgreSQL
# 📊 Tabela: dengue_silver
# 📁 Registros: 1,668,787

# %% [markdown]
# ---
# ## 10. Resumo do ETL

# %%
# ============================================================
# RESUMO DO ETL E VERIFICAÇÃO
# ============================================================

print("=" * 70)
print("📊 RESUMO DO ETL - RAW → SILVER (PostgreSQL)")
print("=" * 70)

# Ler de volta do PostgreSQL para verificar
df_check = spark.read.jdbc(url=JDBC_URL, table=TABLE_NAME, properties=jdbc_properties)

# Cachear para evitar múltiplas leituras (reduz stages visíveis)
df_check.cache()

# Coletar todas as métricas de uma vez para evitar múltiplos stages
metricas = df_check.agg(
    F.count("*").alias("total"),
    F.sum("fl_confirmado").alias("confirmados"),
    F.sum("fl_grave").alias("graves"),
    F.sum("fl_obito").alias("obitos"),
    F.sum("fl_hospitalizado").alias("hospitalizados"),
    F.min("data_notificacao").alias("data_inicio"),
    F.max("data_notificacao").alias("data_fim"),
    F.countDistinct("uf_sigla").alias("total_ufs")
).collect()[0]

# Distribuição por UF (coletada de uma vez)
dist_uf = df_check.groupBy("uf_sigla").count().orderBy(F.desc("count")).collect()

# Liberar cache
df_check.unpersist()

# ============================================================
# EXIBIR RESULTADOS
# ============================================================

print(f"\n📁 VOLUME DE DADOS:")
print(f"   Registros na tabela: {metricas['total']:,}")
print(f"   Colunas: {len(df_check.columns)}")

print(f"\n🏥 INDICADORES EPIDEMIOLÓGICOS:")
print(f"   Casos confirmados: {metricas['confirmados']:,}")
print(f"   Casos graves: {metricas['graves']:,}")
print(f"   Óbitos: {metricas['obitos']:,}")
print(f"   Hospitalizações: {metricas['hospitalizados']:,}")

# Calcular taxas
if metricas['confirmados'] > 0:
    taxa_gravidade = (metricas['graves'] / metricas['confirmados']) * 100
    taxa_letalidade = (metricas['obitos'] / metricas['confirmados']) * 100
    taxa_hosp = (metricas['hospitalizados'] / metricas['confirmados']) * 100
    print(f"\n📈 TAXAS (sobre confirmados):")
    print(f"   Taxa de gravidade: {taxa_gravidade:.2f}%")
    print(f"   Taxa de letalidade: {taxa_letalidade:.2f}%")
    print(f"   Taxa de hospitalização: {taxa_hosp:.2f}%")

print(f"\n📅 PERÍODO:")
print(f"   De: {metricas['data_inicio']}")
print(f"   Até: {metricas['data_fim']}")

print(f"\n📍 COBERTURA GEOGRÁFICA:")
print(f"   Total de UFs: {metricas['total_ufs']}")
print(f"\n   Top 5 UFs por notificações:")
for i, row in enumerate(dist_uf[:5], 1):
    print(f"   {i}. {row['uf_sigla']}: {row['count']:,}")

print(f"\n" + "=" * 70)
print(f"✅ ETL CONCLUÍDO COM SUCESSO!")
print(f"   Destino: PostgreSQL → {POSTGRES_CONFIG['host']}:{POSTGRES_CONFIG['port']}/{POSTGRES_CONFIG['database']}")
print(f"   Tabela: {TABLE_NAME}")
print("=" * 70)
# Out:
# ...
# 📊 RESUMO DO ETL - RAW → SILVER (PostgreSQL)
# ...
# 📁 VOLUME DE DADOS:
#    Registros na tabela: 1,668,787
#    Colunas: 73
#
# 🏥 INDICADORES EPIDEMIOLÓGICOS:
#    Casos confirmados: 1,448,318
#    Casos graves: 37,213
#    Óbitos: 1,773
#    Hospitalizações: 72,708
#
# 📈 TAXAS (sobre confirmados):
#    Taxa de gravidade: 2.57%
#    Taxa de letalidade: 0.12%
#    Taxa de hospitalização: 5.02%
#
# 📅 PERÍODO:
#    De: 2024-12-29
#    Até: 2026-01-05
#
# 📍 COBERTURA GEOGRÁFICA:
#    Total de UFs: 27
#
#    Top 5 UFs por notificações:
#    1. SP: 904,577
#    2. MG: 167,580
#    3. PR: 111,683
#    4. GO: 102,973
#    5. RS: 85,812
#
# ...
# ✅ ETL CONCLUÍDO COM SUCESSO!
#    Destino: PostgreSQL → localhost:5432/gis
#    Tabela: dengue_silver
# ...
